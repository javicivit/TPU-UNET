# %% [markdown]
# <a href="https://colab.research.google.com/github/javicivit/TPU-UNET/blob/master/GPU_version_TPU_U_Net_Cup_Disc_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Training of a modified U-Net for Optic Disc/Cup on RIM-ONE v3  & DRISHTI databases.
#
# We use publicly available RIM-ONE v3, DRISHTI and DRIONS datasets. The use of multiple datasets both for training and for validation allows our system to be more independent of the capture devices than other available implementations. RIM ONE-v3, from the MIAG group of the University of La Laguna (Spain), consists of 159 fundus images which have been labeled by expert ophthalmologists for both disc and cup. DRISHTI-GS, from Aravind Eye hospital, Madurai, India consists of 101 fundus images also labeled for disc and cup. DRIONS-DB from Miguel Servet Hospital, Saragossa (Spain), consists of 110 images on which only the optic cup has been labelled.
# Fundus images and disk maskks are resized in one sted to 128x128.  The hdf versions of the Datasets can be uploaded from [Sevastopolsky's github](https://github.com/seva100/optic-nerve-cnn)

# %% [markdown]
# # Train with RIM one and DRISHTI
# ## TPU based UNET Segmentation.
#
# The colaboratory demostrates  the segmentation of Fundus images using the very well known U-Net network in Keras.
# This work is originally based on:
# [Sevastopolsky A., Optic disc and cup segmentation methods for glaucoma detection with modification of U-Net convolutional neural network, Pattern Recognition and Image Analysis 27 (2017), no. 3, 618–624](https://github.com/seva100/optic-nerve-cnn )
#
# The code was rewriten and adapted to TPU based trainning by Javier Civit and Anton Civit. The main modifications are:
# * We use a completely different dual image generator and use it for both training and testing. For TPU training we need much larger static datasets and, thus we also make use of static data augmentation including images with modified brightness and modified parameters for the adaptive histogram equalization. This, together with the use of images from three different publicly available datasets for training and validation improves the robustness to the use if images acquired with different instruments.
# * We use the version of Keras included in tensorflow. This is necessary to be able to execute in TPUs.
# * We use [Pröve's parameterizable recursive U-net model](https://github.com/pietz/unet-keras). This model allows us to easily change many parameters necessary to compare different implementations of U-Net. Specifically, we can change the network depth and with, the use of drop out and batch normalization, the use of upsampling (although this type of layer is not currently supported by Keras in TPUs) nor transpose convolution and the width ratio between successive layers
# * We use much larger image batches for both training and testing and training. We use an Adam optimizer algorithm in most cases with a .00075 learning rate although in a few cases, we have had to lower this value to ensure convergence. This values have proven suitable for TPU based training in U-Net architecture and provide good results with good training times even in the most complex implementations.
# * In the last version we have modified the Dataset balance and use binary crossentropy loss as this seems to work better in tensorflow 13.1
# * We will provide a TF 2.0 version in the near future

# %% [markdown]
# ####Lets load the data from Gdrive
# We will use the colab interface to google drive. See: https://colab.research.google.com/notebooks/io.ipynb

# %%
# !pip install tensorflow==1.13.1
# Out:
# Collecting tensorflow==1.13.1
#   Downloading https://files.pythonhosted.org/packages/77/63/a9fa76de8dffe7455304c4ed635be4aa9c0bacef6e0633d87d5f54530c5c/tensorflow-1.13.1-cp36-cp36m-manylinux1_x86_64.whl (92.5MB)
#      |████████████████████████████████| 92.5MB 1.2MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Collecting tensorboard<1.14.0,>=1.13.0 (from tensorflow==1.13.1)
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 33.2MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.8.0)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0 (from tensorflow==1.13.1)
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
#      |████████████████████████████████| 368kB 40.4MB/s
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.0.8)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.16.5)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.33.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (0.15.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.1.1)
# Collecting mock>=2.0.0 (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1)
#   Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.13.1) (41.2.0)
# Installing collected packages: tensorboard, mock, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed mock-3.0.5 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Colab drive only allows file open, read and write thus we define our own copy function:

# %% [markdown]
# Let's import the required libraries:

# %%
import tensorflow as tf


import os
import glob
from datetime import datetime
#import warnings
#warnings.simplefilter('ignore')
import scipy as sp
import scipy.ndimage
import numpy as np
import pandas as pd
import skimage
import skimage.exposure
import skimage.transform
import skimage.measure
#from sklearn.cross_validation import KFold
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import h5py
from tqdm import tqdm_notebook
#import mahotas as mh
from IPython.display import display
#from dual_IDG import DualImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers as layers
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, \
    Conv2D, MaxPooling2D, ZeroPadding2D, Input, Embedding, LSTM,  \
    Lambda, UpSampling2D,concatenate,Conv2DTranspose,Concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD, Adam, Adagrad
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import math

# %%
K.set_floatx('float32')

# %% [markdown]
# Our loss function is based on dice (intersectionover union).
# We use -log(dice) as our loss function as this seems to work better but, of course you can play with it.
# This is based on: https://github.com/EdwardTyantov/ultrasound-nerve-segmentation

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
  
def dice_loss(y_true,y_pred):
    return -dice_coef(y_true,y_pred)
  
def log_dice_loss(y_true, y_pred):
    return -K.log(dice_coef(y_true, y_pred))

# %%
def iou_loss_core(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    union = K.sum(y_true,-1) + K.sum(y_pred,-1) - intersection
    iou = (intersection + smooth) / ( union + smooth)
    return iou

# %% [markdown]
# Auxiliary function to modify image brightness.

# %%
def modify_brightness_p(img, p=1.2):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 1.0/p
    v[v > lim] = 1.0
    v[v <= lim] *= p
    #print(np.amax(v))

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR).clip(min=0)
    return img

# %% [markdown]
# Auxiliary funtion to shuffle to vectors in a coherent way:

# %%
def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %% [markdown]
# Auxiliary function to use 512 image size indexes with original images.

# %%
def index512_resize(index,top):
  index=index*top/512
  return int(index)

# %% [markdown]
# Our data is in hdf5 (https://www.h5py.org/) format
# Train/test with  Drishti and RimONE

# %%
#h5f1 = h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'content/gdrive/My Drive', 'all_data.hd5f'), 'r')
h5f1 = h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'content/gdrive/My Drive', 'RIM_ONE_v3.hdf5'), 'r')

# %%
h5f2=h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'content/gdrive/My Drive', 'DRISHTI_GS.hdf5'), 'r')

# %%
h5v1=h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'content/gdrive/My Drive', 'DRIONS_DB.hdf5'), 'r')

# %% [markdown]
# ### U-Net architecture
#
# We use a version of the net presented in: https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/
# The generalized U-Net is based on https://github.com/pietz/unet-keras

# %%
'''
U-Net: Convolutional Networks for Biomedical Image Segmentation
(https://arxiv.org/abs/1505.04597)
---
img_shape: (height, width, channels)
out_ch: number of output channels
start_ch: number of channels of the first conv
depth: zero indexed depth of the U-structure
inc_rate: rate at which the conv channels will increase
activation: activation function after convolutions
dropout: amount of dropout in the contracting part
batchnorm: adds Batch Normalization if true
maxpool: use strided conv instead of maxpooling if false
upconv: use transposed conv instead of upsamping + conv if false
residual: add residual connections around each conv block if true
'''

def conv_block(m, dim, acti, bn, res, do=0):
	n = Conv2D(dim, 3, activation=acti, padding='same')(m)
	n = BatchNormalization()(n) if bn else n
	n = Dropout(do)(n) if do else n
	n = Conv2D(dim, 3, activation=acti, padding='same')(n)
	n = BatchNormalization()(n) if bn else n
	return Concatenate()([m, n]) if res else n

def level_block(m, dim, depth, inc, acti, do, bn, mp, up, res):
	if depth > 0:
		n = conv_block(m, dim, acti, bn, res)
		m = MaxPooling2D()(n) if mp else Conv2D(dim, 3, strides=2, padding='same')(n)
		m = level_block(m, int(inc*dim), depth-1, inc, acti, do, bn, mp, up, res)
		if up:
			m = UpSampling2D()(m)
			m = Conv2D(dim, 2, activation=acti, padding='same')(m)
		else:
			m = Conv2DTranspose(dim, 3, strides=2, activation=acti, padding='same')(m)
		n = concatenate([n, m],axis=-1)
		m = conv_block(n, dim, acti, bn, res)
	else:
		m = conv_block(m, dim, acti, bn, res, do)
	return m

def UNet(img_shape, out_ch=1, start_ch=64, depth=4, inc_rate=2., activation='relu', 
		 dropout=0.5, batchnorm=False, maxpool=True, upconv=True, residual=False):
	i = Input(shape=img_shape)
	o = level_block(i, start_ch, depth, inc_rate, activation, dropout, batchnorm, maxpool, upconv, residual)
	o = Conv2D(out_ch, 1, activation='sigmoid')(o)
	return Model(inputs=i, outputs=o)

# %% [markdown]
# Change these parameters according to  the architecture . Uss Cup=True to segment the Cup and False to segment the disk.

# %%
img_shape=(128,128,3)

# %% [markdown]
# Lets visualize the model and save its graphical representation.

# %%
cup=True
name='mX_TI_Cupd6w72ir12bn'
model=UNet(img_shape,start_ch=72,upconv=False,dropout=0.2, depth=6,inc_rate=1.2, batchnorm=True, residual=False)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 72) 2016        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 128, 128, 72) 288         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 72) 46728       batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 128, 128, 72) 288         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 72)   0           batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 86)   55814       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 64, 64, 86)   344         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 86)   66650       batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 64, 64, 86)   344         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 86)   0           batch_normalization_v1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 103)  79825       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 32, 32, 103)  412         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 103)  95584       batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 32, 32, 103)  412         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 103)  0           batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 123)  114144      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 16, 16, 123)  492         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 123)  136284      batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 16, 16, 123)  492         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 123)    0           batch_normalization_v1_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 147)    162876      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 8, 8, 147)    588         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 147)    194628      batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 8, 8, 147)    588         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 147)    0           batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 176)    233024      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 4, 4, 176)    704         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 176)    278960      batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 4, 4, 176)    704         conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 176)    0           batch_normalization_v1_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 2, 211)    334435      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_12 (Batc (None, 2, 2, 211)    844         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2, 2, 211)    0           batch_normalization_v1_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 2, 2, 211)    400900      dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_13 (Batc (None, 2, 2, 211)    844         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 4, 4, 176)    334400      batch_normalization_v1_13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 4, 352)    0           batch_normalization_v1_11[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 176)    557744      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_14 (Batc (None, 4, 4, 176)    704         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 176)    278960      batch_normalization_v1_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_15 (Batc (None, 4, 4, 176)    704         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 147)    232995      batch_normalization_v1_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 294)    0           batch_normalization_v1_9[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 147)    389109      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_16 (Batc (None, 8, 8, 147)    588         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 147)    194628      batch_normalization_v1_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_17 (Batc (None, 8, 8, 147)    588         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 123)  162852      batch_normalization_v1_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 246)  0           batch_normalization_v1_7[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 123)  272445      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_18 (Batc (None, 16, 16, 123)  492         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 123)  136284      batch_normalization_v1_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_19 (Batc (None, 16, 16, 123)  492         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 103)  114124      batch_normalization_v1_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 206)  0           batch_normalization_v1_5[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 103)  191065      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_20 (Batc (None, 32, 32, 103)  412         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 103)  95584       batch_normalization_v1_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_21 (Batc (None, 32, 32, 103)  412         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 86)   79808       batch_normalization_v1_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 172)  0           batch_normalization_v1_3[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 86)   133214      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_22 (Batc (None, 64, 64, 86)   344         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 86)   66650       batch_normalization_v1_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_23 (Batc (None, 64, 64, 86)   344         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 128, 128, 72) 55800       batch_normalization_v1_23[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 144 0           batch_normalization_v1_1[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 72) 93384       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_24 (Batc (None, 128, 128, 72) 288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 72) 46728       batch_normalization_v1_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_25 (Batc (None, 128, 128, 72) 288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 1)  73          batch_normalization_v1_25[0][0]
# ==================================================================================================
# Total params: 5,650,715
# Trainable params: 5,644,215
# Non-trainable params: 6,500
# __________________________________________________________________________________________________

# %%
# Plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='/content/gdrive/My Drive/model.png')
from IPython.display import Image
Image(retina=True, filename='/content/gdrive/My Drive/model.png')

# %% [markdown]
# We are using the Adan optimizer https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/ .

# %% [markdown]
# **DRISHTI RIM ONE CUP Aggressive augmentation**
#
# Accessing data, preparing train/validation sets: Resize & Prepare

# %%
Xori= h5f2['DRISHTI-GS/orig/images']
disc_locations = h5f2['DRISHTI-GS/512 px/disc_locations']
isize=Xori.shape[1]

if(cup):
  Yf = h5f2['DRISHTI-GS/512 px/cup']
  Xc = [Xori[i][index512_resize(disc_locations[i][0],isize):index512_resize(disc_locations[i][2],isize), index512_resize(disc_locations[i][1],isize):index512_resize(disc_locations[i][3],isize)] 
                   for i in range(len(Xori))]

  Yc=[Yf[i][disc_locations[i][0]:disc_locations[i][2], disc_locations[i][1]:disc_locations[i][3]] 
                   for i in range(len(Xori))]
else:
  Yf = h5f2['DRISHTI-GS/512 px/disc']
  Xc = [Xori[i][index512_resize(50,isize):index512_resize(462,isize), index512_resize(50,isize):index512_resize(462,isize)] 
                   for i in range(len(Xori))]

  Yc=[Yf[i][50:462,50:462] 
                   for i in range(len(Xori))]

Xa=[cv2.resize(img, (128, 128),interpolation=cv2.INTER_NEAREST) for img in Xc]
X=[skimage.exposure.equalize_adapthist(img, clip_limit=0.035)  for img in Xa]
X=np.asarray(X) 
am=np.amax(X)
X=X.astype(np.float32)/am 
print(np.amax(X),np.amin(X))

Y=[cv2.resize(img, (128, 128),interpolation=cv2.INTER_NEAREST)[..., None] for img in Yc]
Y=np.asarray(Y) 
ym=np.amax(Y) 
Yf=Y/ym 
Yb=(Y>0.5).astype(np.float32) #get binary mask


print(np.amax(Yf),np.amin(Yf))
print(X.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# 1.0 0.0
# 1.0 0.0
# (50, 128, 128, 3)

# %%
Xvori= h5f1['RIM-ONE v3/orig/images']
disc_locationsv = h5f1['RIM-ONE v3/512 px/disc_locations']
ivsize=Xvori.shape[1]
if (cup):
  Yvf = h5f1['RIM-ONE v3/512 px/cup']
  Xvc = [Xvori[i][index512_resize(disc_locationsv[i][0],ivsize):index512_resize(disc_locationsv[i][2],ivsize), index512_resize(disc_locationsv[i][1],ivsize):index512_resize(disc_locationsv[i][3],ivsize)] 
                     for i in range(len(Xvori))]

  Yvc=[Yvf[i][disc_locationsv[i][0]:disc_locationsv[i][2], disc_locationsv[i][1]:disc_locationsv[i][3]] 
                     for i in range(len(Xvori))]

else:
  Yvf = h5f1['RIM-ONE v3/512 px/disc']
  Xvc = [Xvori[i][index512_resize(50,isize):index512_resize(462,ivsize), index512_resize(50,isize):index512_resize(462,ivsize)] 
                     for i in range(len(Xvori))]

  Yvc=[Yvf[i][50:462,50:462] 
                     for i in range(len(Xvori))]


Xvn=[cv2.resize(img, (128, 128),interpolation=cv2.INTER_NEAREST) for img in Xvc]
Xv=[skimage.exposure.equalize_adapthist(img, clip_limit=0.035)  for img in Xvn]

Xv=np.asarray(Xv) 
am=np.amax(Xv)
Xv=Xv.astype(np.float32)/am 
print(np.amax(Xv),np.amin(Xv))

Yv=[cv2.resize(img, (128, 128),interpolation=cv2.INTER_NEAREST)[..., None] for img in Yvc]

Yv=np.asarray(Yv) 
ym=np.amax(Yv) 
Yvf=(Yv/ym).astype(np.float32) 
print(np.amax(Yvf),np.amin(Yvf))
print(Xv.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# 1.0 0.0
# 1.0 0.0
# (159, 128, 128, 3)

# %% [markdown]
# Create more "data". Just copy the vectors over themselves and add modified versions so that the generators can  produce longer batches & Distibute between train & test

# %%
rng = np.random.RandomState(42)
#X=np.concatenate([X,Xv])
#Yf=np.concatenate([Yf,Yvf])
  
X_train1t, X_test1t, Y_train1t, Y_test1t = train_test_split( X, Yb, test_size=0.25,random_state=rng)
X_train2, X_test2, Y_train2, Y_test2 = train_test_split( Xv, Yvf, test_size=0.25,random_state=rng)
print(X_train1t.shape[0],X_train2.shape[0],Y_train1t.shape[0],Y_train2.shape[0])

X_train1=np.concatenate([X_train1t,X_train1t])
X_train1=np.concatenate([X_train1,X_train1t])
#X_train1=np.concatenate([X_train1,X_train1t]) 

X_test1=np.concatenate([X_test1t,X_test1t])
X_test1=np.concatenate([X_test1,X_test1t])

Y_train1=np.concatenate([Y_train1t,Y_train1t])
Y_train1=np.concatenate([Y_train1,Y_train1t])
#Y_train1=np.concatenate([Y_train1,Y_train1t]) 

Y_test1=np.concatenate([Y_test1t,Y_test1t])
Y_test1=np.concatenate([Y_test1,Y_test1t])


X_train1=np.concatenate([X_train1,X_train2])
Y_train1=np.concatenate([Y_train1,Y_train2])
X_test=np.concatenate([X_test1,X_test2])
Y_test=np.concatenate([Y_test1,Y_test2])


X_train1=np.asarray(X_train1)
Y_train1=np.asarray(Y_train1)
X_test=np.asarray(X_test)
Y_test=np.asarray(Y_test)

X_train=np.copy(X_train1)
Y_train=np.copy(Y_train1)

size=X_train1.shape[0]

print(size,3160/size, Y_train1.shape[0])

X_traine=np.empty((20*size, 128, 128, 3),dtype=np.float32)
Y_traine=np.empty((20*size, 128, 128, 1),dtype=np.float32)



for i in range(16):
  #print(i*size,(i+1)*size)
  X_traine[i*size:(i+1)*size]=X_train1
  Y_traine[i*size:(i+1)*size]=Y_train1
  
base= 16*size

for j in tqdm_notebook(range(X_train1.shape[0])):
  X_traine[base]=skimage.exposure.equalize_adapthist(X_train1[j], clip_limit=0.4)
  Y_traine[base]=Y_train1[j]
  base+=1
  X_traine[base]=skimage.exposure.equalize_adapthist(X_train1[j], clip_limit=0.2)
  Y_traine[base]=Y_train1[j]
  base+=1
  X_traine[base]=modify_brightness_p(X_train1[j],0.9)
  Y_traine[base]=Y_train1[j]
  base+=1
  X_traine[base]=modify_brightness_p(X_train1[j],1.1)
  Y_traine[base]=Y_train1[j]
  base+=1

  
X_testc=np.copy(X_test)
Y_testc=np.copy(Y_test)

sizev=X_testc.shape[0]

X_teste=np.empty((sizev*20, 128, 128, 3),dtype=np.float32)
Y_teste=np.empty((sizev*20, 128, 128, 1),dtype=np.float32)

for i in range(16):
  X_teste[i*sizev:(i+1)*sizev]=X_testc
  Y_teste[i*sizev:(i+1)*sizev]=Y_testc
  
basev= 16*sizev

for j in tqdm_notebook(range(X_testc.shape[0])):
  X_teste[basev]=skimage.exposure.equalize_adapthist(X_testc[j], clip_limit=0.4)
  Y_teste[basev]=Y_testc[j]
  basev+=1
  X_teste[basev]=skimage.exposure.equalize_adapthist(X_testc[j], clip_limit=0.2)
  Y_teste[basev]=Y_testc[j]
  basev+=1
  X_teste[basev]=modify_brightness_p(X_testc[j],0.9)
  Y_teste[basev]=Y_testc[j]
  basev+=1
  X_teste[basev]=modify_brightness_p(X_testc[j],1.1)
  Y_teste[basev]=Y_testc[j]
  basev+=1
# Out:
# 37 119 37 119
# 230 13.73913043478261 230
# HBox(children=(IntProgress(value=0, max=230), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float32 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to float32
#   .format(dtypeobj_in, dtypeobj_out))
# HBox(children=(IntProgress(value=0, max=79), HTML(value='')))

# %%
print(X_traine.shape,Y_traine.shape,X_teste.shape,Y_teste.shape)
# Out:
# (4600, 128, 128, 3) (4600, 128, 128, 1) (1580, 128, 128, 3) (1580, 128, 128, 1)

# %% [markdown]
# ***Aumented dual image generator***
# Based on the example at:
# https://keras.io/preprocessing/image/#imagedatagenerator-class
# Had to modified as zipped version is currently not accepted

# %%
X_trains,Y_trains=unison_shuffled_copies(X_traine, Y_traine)

# %%
X_tests,Y_tests=unison_shuffled_copies(X_teste, Y_teste)

# %%
# Provide the same seed and keyword arguments to the fit and flow methods
seed=42
#batch_s=450
batch_s=96 #conv_Trans will not run in GPU with 128

# %%
data_gen_args = dict(#rescale=1./255,
                     #featurewise_center=True,
                     #featurewise_std_normalization=True,
                     horizontal_flip=True, vertical_flip=True,
                     rotation_range=30,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.2,
                     fill_mode='constant', cval=0.0, 
                     #brightness_range=[-0.1,0.1],
                     #preprocessing_function=skimage.exposure.equalize_adapthist,
                     dtype='float32'
                     )
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

image_generator = image_datagen.flow(
    X_trains,
    batch_size=batch_s,
    seed=seed)

mask_generator = mask_datagen.flow(
    Y_trains,
    batch_size=batch_s,
    seed=seed)

#train_generator = zip(image_generator, mask_generator)
def train_generator():
  while True:
    yield image_generator.next(),mask_generator.next()
    

image_generator_test = image_datagen.flow(
    X_tests,
    batch_size=batch_s,
    seed=seed)

mask_generator_test = mask_datagen.flow(
    Y_tests,
    batch_size=batch_s,
    seed=seed)

#test_generator = zip(image_generator_test, mask_generator_test)
def test_generator():
  while True:
    yield image_generator_test.next(),mask_generator_test.next()

# %% [markdown]
# Set the place for localy saving the weights. After training we will copy to Gdrive

# %% [markdown]
# ###Train on GPU

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.00075 ), loss=log_dice_loss, metrics=[dice_coef])

# %%
checkpointer = ModelCheckpoint(filepath=os.path.join('/content/gdrive/My Drive/GPU/'+name+'last_checkpoint_TPU.hdf5'), verbose=1, save_best_only=True)

# %%
# %%time 
history=model.fit_generator(
                           train_generator(),
                           steps_per_epoch = 200,
                           validation_data = test_generator(),
                           validation_steps = 30,
                         
                            epochs=25,
                           callbacks=[checkpointer]
)
# Out:
# Epoch 1/25
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(56,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(56, 128, 128, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(56, 128, 128, 1), dtype=tf.float32, name='conv2d_26_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 27.889119386672974 secs
# INFO:tensorflow:Setting weights on TPU model.
# 10/40 [======>.......................] - ETA: 7:10 - loss: 0.5148 - acc: 0.7869INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(12,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(12, 128, 128, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(12, 128, 128, 1), dtype=tf.float32, name='conv2d_26_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 19.24825954437256 secs
# 39/40 [============================>.] - ETA: 10s - loss: 0.2742 - acc: 0.8927INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(56,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(56, 128, 128, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(56, 128, 128, 1), dtype=tf.float32, name='conv2d_26_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 26.807971000671387 secs
# 3/6 [==============>...............] - ETA: 31s - loss: 0.5453 - acc: 0.7767 INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(28,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(28, 128, 128, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(28, 128, 128, 1), dtype=tf.float32, name='conv2d_26_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 23.021679639816284 secs
# 6/6 [==============================] - 59s 10s/step - loss: 0.5425 - acc: 0.7779
#
# Epoch 00001: val_loss improved from inf to 0.54251, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 40/40 [==============================] - 555s 14s/step - loss: 0.2707 - acc: 0.8941 - val_loss: 0.5425 - val_acc: 0.7779
# Epoch 2/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.6347 - acc: 0.8048
#
# Epoch 00002: val_loss did not improve from 0.54251
# 40/40 [==============================] - 351s 9s/step - loss: 0.1188 - acc: 0.9468 - val_loss: 0.6347 - val_acc: 0.8048
# Epoch 3/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.5621 - acc: 0.8575
#
# Epoch 00003: val_loss did not improve from 0.54251
# 40/40 [==============================] - 352s 9s/step - loss: 0.1066 - acc: 0.9508 - val_loss: 0.5621 - val_acc: 0.8575
# Epoch 4/25
# 6/6 [==============================] - 9s 2s/step - loss: 1.7494 - acc: 0.8011
#
# Epoch 00004: val_loss did not improve from 0.54251
# 40/40 [==============================] - 351s 9s/step - loss: 0.1016 - acc: 0.9534 - val_loss: 1.7494 - val_acc: 0.8011
# Epoch 5/25
# 6/6 [==============================] - 9s 1s/step - loss: 1.4148 - acc: 0.7983
#
# Epoch 00005: val_loss did not improve from 0.54251
# 40/40 [==============================] - 349s 9s/step - loss: 0.0912 - acc: 0.9544 - val_loss: 1.4148 - val_acc: 0.7983
# Epoch 6/25
# 6/6 [==============================] - 10s 2s/step - loss: 1.1622 - acc: 0.8204
#
# Epoch 00006: val_loss did not improve from 0.54251
# 40/40 [==============================] - 351s 9s/step - loss: 0.0825 - acc: 0.9580 - val_loss: 1.1622 - val_acc: 0.8204
# Epoch 7/25
# 6/6 [==============================] - 10s 2s/step - loss: 1.6671 - acc: 0.7572
#
# Epoch 00007: val_loss did not improve from 0.54251
# 40/40 [==============================] - 352s 9s/step - loss: 0.0757 - acc: 0.9601 - val_loss: 1.6671 - val_acc: 0.7572
# Epoch 8/25
# 6/6 [==============================] - 10s 2s/step - loss: 1.0719 - acc: 0.7858
#
# Epoch 00008: val_loss did not improve from 0.54251
# 40/40 [==============================] - 352s 9s/step - loss: 0.0741 - acc: 0.9610 - val_loss: 1.0719 - val_acc: 0.7858
# Epoch 9/25
# 6/6 [==============================] - 9s 2s/step - loss: 1.4323 - acc: 0.7773
#
# Epoch 00009: val_loss did not improve from 0.54251
# 40/40 [==============================] - 351s 9s/step - loss: 0.0709 - acc: 0.9620 - val_loss: 1.4323 - val_acc: 0.7773
# Epoch 10/25
# 6/6 [==============================] - 10s 2s/step - loss: 1.6544 - acc: 0.7531
#
# Epoch 00010: val_loss did not improve from 0.54251
# 40/40 [==============================] - 352s 9s/step - loss: 0.0737 - acc: 0.9605 - val_loss: 1.6544 - val_acc: 0.7531
# Epoch 11/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.9887 - acc: 0.8117
#
# Epoch 00011: val_loss did not improve from 0.54251
# 40/40 [==============================] - 350s 9s/step - loss: 0.0642 - acc: 0.9641 - val_loss: 0.9887 - val_acc: 0.8117
# Epoch 12/25
# 6/6 [==============================] - 9s 2s/step - loss: 0.6122 - acc: 0.8598
#
# Epoch 00012: val_loss did not improve from 0.54251
# 40/40 [==============================] - 348s 9s/step - loss: 0.0658 - acc: 0.9638 - val_loss: 0.6122 - val_acc: 0.8598
# Epoch 13/25
# 6/6 [==============================] - 9s 2s/step - loss: 0.6773 - acc: 0.8456
#
# Epoch 00013: val_loss did not improve from 0.54251
# 40/40 [==============================] - 350s 9s/step - loss: 0.0592 - acc: 0.9660 - val_loss: 0.6773 - val_acc: 0.8456
# Epoch 14/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.4316 - acc: 0.8869
#
# Epoch 00014: val_loss improved from 0.54251 to 0.43156, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 40/40 [==============================] - 356s 9s/step - loss: 0.0572 - acc: 0.9668 - val_loss: 0.4316 - val_acc: 0.8869
# Epoch 15/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.2326 - acc: 0.9263
#
# Epoch 00015: val_loss improved from 0.43156 to 0.23263, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 40/40 [==============================] - 359s 9s/step - loss: 0.0348 - acc: 0.9715 - val_loss: 0.2326 - val_acc: 0.9263
# Epoch 16/25
# 6/6 [==============================] - 9s 2s/step - loss: 0.1897 - acc: 0.9329
#
# Epoch 00016: val_loss improved from 0.23263 to 0.18965, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 40/40 [==============================] - 356s 9s/step - loss: 0.0345 - acc: 0.9714 - val_loss: 0.1897 - val_acc: 0.9329
# Epoch 17/25
# 6/6 [==============================] - 9s 1s/step - loss: 0.1848 - acc: 0.9379
#
# Epoch 00017: val_loss improved from 0.18965 to 0.18477, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# 40/40 [==============================] - 357s 9s/step - loss: 0.0319 - acc: 0.9720 - val_loss: 0.1848 - val_acc: 0.9379
# Epoch 18/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.1797 - acc: 0.9373
#
# Epoch 00018: val_loss improved from 0.18477 to 0.17971, saving model to /content/gdrive/My Drive/GPU/mX_TI_Cupd6w72ir12bnlast_checkpoint_TPU.hdf5
# INFO:tensorflow:Copying TPU weights to the CPU
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 40/40 [==============================] - 358s 9s/step - loss: 0.0291 - acc: 0.9730 - val_loss: 0.1797 - val_acc: 0.9373
# Epoch 19/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.1849 - acc: 0.9396
#
# Epoch 00019: val_loss did not improve from 0.17971
# 40/40 [==============================] - 350s 9s/step - loss: 0.0305 - acc: 0.9725 - val_loss: 0.1849 - val_acc: 0.9396
# Epoch 20/25
# 6/6 [==============================] - 9s 2s/step - loss: 0.2033 - acc: 0.9421
#
# Epoch 00020: val_loss did not improve from 0.17971
# 40/40 [==============================] - 352s 9s/step - loss: 0.0692 - acc: 0.9634 - val_loss: 0.2033 - val_acc: 0.9421
# Epoch 21/25
# 6/6 [==============================] - 9s 1s/step - loss: 0.2264 - acc: 0.9363
#
# Epoch 00021: val_loss did not improve from 0.17971
# 40/40 [==============================] - 350s 9s/step - loss: 0.0573 - acc: 0.9673 - val_loss: 0.2264 - val_acc: 0.9363
# Epoch 22/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.2203 - acc: 0.9312
#
# Epoch 00022: val_loss did not improve from 0.17971
# 40/40 [==============================] - 352s 9s/step - loss: 0.0524 - acc: 0.9687 - val_loss: 0.2203 - val_acc: 0.9312
# Epoch 23/25
# 6/6 [==============================] - 10s 2s/step - loss: 0.1954 - acc: 0.9379
#
# Epoch 00023: val_loss did not improve from 0.17971
# 40/40 [==============================] - 350s 9s/step - loss: 0.0483 - acc: 0.9695 - val_loss: 0.1954 - val_acc: 0.9379
# Epoch 24/25
# 6/6 [==============================] - 9s 2s/step - loss: 0.1898 - acc: 0.9381
#
# Epoch 00024: val_loss did not improve from 0.17971
# 40/40 [==============================] - 352s 9s/step - loss: 0.0457 - acc: 0.9703 - val_loss: 0.1898 - val_acc: 0.9381
# Epoch 25/25
# 6/6 [==============================] - 9s 1s/step - loss: 0.2080 - acc: 0.9363
#
# Epoch 00025: val_loss did not improve from 0.17971
# 40/40 [==============================] - 349s 9s/step - loss: 0.0461 - acc: 0.9703 - val_loss: 0.2080 - val_acc: 0.9363
# CPU times: user 34min 20s, sys: 1min 26s, total: 35min 47s
# Wall time: 2h 30min 4s

# %% [markdown]
# Save weights on Gdrive. Ajust destination File as desired

# %% [markdown]
# **Chart Accuracy and Loss**

# %%
loss = history.history['loss']
val_loss=history.history['val_loss']
#acc=history.history['dice_coef']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(4.5, 2.5))
plt.plot(epochs, loss, 'b', label='Training loss')
# bo is blue dots
plt.plot(epochs, val_loss, 'bo', label='Test loss')
# b is for "solid blue line"
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

#plt.show()
plt.savefig(os.path.join('/content/gdrive/My Drive/FIG','loss'+name+'.png'),dpi=600)

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
acc=history.history['acc']
val_acc=history.history['val_acc']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(4.5, 2.5))
plt.plot(epochs, acc, 'b', label='Dice')
# bo is blue dots
plt.plot(epochs, val_acc, 'bo', label='Test dice')
# b is for "solid blue line"
plt.title('Training and test Dice')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()

#plt.show()
plt.savefig(os.path.join('/content/gdrive/My Drive/FIG','hist'+name+'.png'),dpi=600)

# %% [markdown]
# ### Comprehensive visual check

# %%
smooth=1e-07

def np_dice_coef(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return ( (2. * intersection + smooth) / 
             (np.sum(y_true_f) + np.sum(y_pred_f) + smooth) )

# %%
def np_iou(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return ( ( intersection + smooth) / 
             (np.sum(y_true_f) + np.sum(y_pred_f) - intersection + smooth) )

# %%
test_s=int(X_testc.shape[0])
test_s=test_s-test_s%8
test_s
# Out:
# 72

# %%
tpu_model.load_weights(os.path.join('/content/gdrive/My Drive/GPU/'+name+'last_checkpoint_TPU.hdf5'))

# %% [markdown]
# Acquiring scores for the validation set:

# %%
# %%time
pred_dice=np.empty((test_s), dtype=np.float32)
pred_iou=np.empty((test_s), dtype=np.float32)


#sess = K.get_session()

batch_X = X_testc[0:test_s]
batch_y = Y_testc[0:test_s]
print (batch_X.shape)
    
predv = (model.predict(batch_X)[...,0]>0.5).astype(np.float32)
corrv= (batch_y)[ ..., 0].astype(np.float32)


for i in tqdm_notebook(range(predv.shape[0])):
    #print('image #{}'.format(i))
    img = X_test[i]
    
    pred = predv[i]
    corr = corrv[i]
    cur_dice = np_dice_coef(pred, corr)
    cur_iou = np_iou(pred,corr)
    #print(cur_dice)
    pred_dice[i]=(cur_dice)
    pred_iou[i]=cur_iou
    
    
d_worst=np.amin(pred_dice)
d_best=np.amax(pred_dice)
d_mean=np.mean(pred_dice)
d_std=np.std(pred_dice)
print("Dice mean=",d_mean, " Std=",d_std, " best=",d_best," worst=",d_worst)

i_worst=np.amin(pred_iou)
i_best=np.amax(pred_iou)
i_mean=np.mean(pred_iou)
i_std=np.std(pred_iou)
print("IOU mean=",i_mean, " Std=",i_std, " best=",i_best," worst=",i_worst)

ix_best=np.argmax(pred_dice)
ix_worst=np.argmin(pred_dice)

j=0
for i in [ix_best,ix_worst]:
    print('image #{}'.format(i))
    img = X_test[i]
    pred = predv[i]
    corr = corrv[i]
    
    print(pred_dice[i])
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    #ax.imshow(img)
    ax.imshow(img)
    ax.set_title('Image')
    #plt.show()
    fig.savefig(os.path.join('/content/gdrive/My Drive/FIG','img'+str(j)+name+'.png'),dpi=600)
    j+=1
# Out:
# (72, 128, 128, 3)
# INFO:tensorflow:New input shapes; (re-)compiling: mode=infer (# of cores 8), [TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name='input_1_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 13.630645513534546 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:New input shapes; (re-)compiling: mode=infer (# of cores 8), [TensorSpec(shape=(1, 128, 128, 3), dtype=tf.float32, name='input_1_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 10.343750476837158 secs
# HBox(children=(IntProgress(value=0, max=72), HTML(value='')))
# Dice mean= 0.86163354  Std= 0.08539366  best= 0.9621871  worst= 0.5975366
# IOU mean= 0.76613605  Std= 0.1235028  best= 0.9271297  worst= 0.42606223
# image #2
# 0.9621871
# image #66
# 0.5975366
# CPU times: user 10.2 s, sys: 1.27 s, total: 11.5 s
# Wall time: 50.8 s

# %%
# %%time

batch_X = X_testc[0:test_s]
batch_y = Y_testc[0:test_s]
print (batch_X.shape)
    
predv = (model.predict(batch_X)[...,0]>0.5).astype(np.float32)
corrv= (batch_y)[ ..., 0].astype(np.float32)
# Out:
# (72, 128, 128, 3)
# CPU times: user 83.4 ms, sys: 93.4 ms, total: 177 ms
# Wall time: 227 ms

# %%
cup_rr= np.empty((test_s), dtype=np.float32)
cup_dc= np.empty((test_s), dtype=np.float32)
cup_ac= np.empty((test_s), dtype=np.float32)
cup_ap= np.empty((test_s), dtype=np.float32)


predc = predv[0, ...].copy()
corrc= corrv[0, ...].copy()
print (predc.shape)

for i in tqdm_notebook(range(test_s), leave=True):
    
    predc = predv[i]
    corrc = corrv[i]
    
    label_pc = skimage.measure.label(predc, connectivity=predc.ndim)
    props_pc = skimage.measure.regionprops(label_pc)
    
    label_cc = skimage.measure.label(corrc, connectivity=corrc.ndim)
    props_cc = skimage.measure.regionprops(label_cc)
    
    sz=len(props_pc)
    if(sz)!=0:
      areap=[props_pc[i].area for i in range(sz)]
      #print(sz,areap)
      k=np.argmax(areap)
    
      xcp = props_pc[k].centroid[0] #x center
      ycp = props_pc[k].centroid[1] #y_center
      ap = props_pc[k].area
    else:
      xpc=0
      ypc=0
      ac=0
    
    xcc = props_cc[0].centroid[0] #x center
    ycc = props_cc[0].centroid[1] #y_center
    ac = props_cc[0].area


    
    if (ap>ac):
      ar=ac/ap
    else:
      ar=ap/ac
      
    dist=math.sqrt((xcp-xcc)*(xcp-xcc)+(ycp-ycc)*(ycp-ycc))
    cup_rr[i]=math.sqrt(ar)
    cup_dc[i]=dist
    cup_ac[i]=ac
    cup_ap[i]=ap
# Out:
# (128, 128)
# HBox(children=(IntProgress(value=0, max=72), HTML(value='')))

# %%
#print(cup_rr)
#print(cup_dc)
print('best radii ratio= {:0.2f}, worst radii ratio= {:0.2f}, worst center distance= {:0.2f}, best center distance= {:0.2f}'.format(np.amax(cup_rr),np.amin(cup_rr),np.amax(cup_dc),np.amin(cup_dc)))
bt90=cup_rr>.85
print('Percentage of images with less than 15% radius error ={:0.2f}'.format(sum(bt90)/test_s))
bt90=cup_rr>.9
print('Percentage of images with less than 10% radius error ={:0.2f}'.format(sum(bt90)/test_s))
# Out:
# best radii ratio= 0.99, worst radii ratio= 0.73, worst center distance= 15.92, best center distance= 0.24
# Percentage of images with less than 15% radius error =0.83
# Percentage of images with less than 10% radius error =0.61

# %%
print(predv.shape)
for i in range(predv.shape[0]):
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(predv[i], cmap=plt.cm.Greys_r)
    plt.show()
# Out:
# (72, 128, 128)

# %% [markdown]
# ###Validation DRI

# %%
test_s=int(X_test1t.shape[0])
test_s=test_s-test_s%8
test_s
# Out:
# 8

# %% [markdown]
# Acquiring scores for the validation set:

# %%
# %%time
pred_dice=np.empty((test_s), dtype=np.float32)
pred_iou=np.empty((test_s), dtype=np.float32)


#sess = K.get_session()

batch_X = X_test1t[0:test_s]
batch_y = Y_test1t[0:test_s]
print (batch_X.shape)
    
predv = (model.predict(batch_X)[...,0]>0.5).astype(np.float32)
corrv= (batch_y)[ ..., 0].astype(np.float32)


for i in tqdm_notebook(range(predv.shape[0])):
    #print('image #{}'.format(i))
    img = X_test[i]
    
    pred = predv[i]
    corr = corrv[i]
    cur_dice = np_dice_coef(pred, corr)
    cur_iou = np_iou(pred,corr)
    #print(cur_dice)
    pred_dice[i]=(cur_dice)
    pred_iou[i]=cur_iou
    
    
d_worst=np.amin(pred_dice)
d_best=np.amax(pred_dice)
d_mean=np.mean(pred_dice)
d_std=np.std(pred_dice)
print("Dice mean=",d_mean, " Std=",d_std, " best=",d_best," worst=",d_worst)

i_worst=np.amin(pred_iou)
i_best=np.amax(pred_iou)
i_mean=np.mean(pred_iou)
i_std=np.std(pred_iou)
print("IOU mean=",i_mean, " Std=",i_std, " best=",i_best," worst=",i_worst)

ix_best=np.argmax(pred_dice)
ix_worst=np.argmin(pred_dice)

j=0
for i in [ix_best,ix_worst]:
    print('image #{}'.format(i))
    img = X_test1t[i]
    pred = predv[i]
    corr = corrv[i]
    
    print(pred_dice[i])
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    #ax.imshow(img)
    ax.imshow(img)
    ax.set_title('Image')
    #plt.show()
    fig.savefig(os.path.join('/content/gdrive/My Drive/FIG','imgDRI'+str(j)+name+'.png'),dpi=600)
    j+=1
# Out:
# (8, 128, 128, 3)
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))
# Dice mean= 0.86724985  Std= 0.07231338  best= 0.9621871  worst= 0.7329064
# IOU mean= 0.7727015  Std= 0.111261144  best= 0.9271297  worst= 0.5784154
# image #2
# 0.9621871
# image #1
# 0.7329064
# CPU times: user 4.62 s, sys: 1.12 s, total: 5.74 s
# Wall time: 5.01 s

# %%
cup_rr= np.empty((test_s), dtype=np.float32)
cup_dc= np.empty((test_s), dtype=np.float32)
cup_ac= np.empty((test_s), dtype=np.float32)
cup_ap= np.empty((test_s), dtype=np.float32)


predc = predv[0, ...].copy()
corrc= corrv[0, ...].copy()
print (predc.shape)

for i in tqdm_notebook(range(test_s), leave=True):
    
    predc = predv[i]
    corrc = corrv[i]
    
    label_pc = skimage.measure.label(predc, connectivity=predc.ndim)
    props_pc = skimage.measure.regionprops(label_pc)
    
    label_cc = skimage.measure.label(corrc, connectivity=corrc.ndim)
    props_cc = skimage.measure.regionprops(label_cc)
    
    sz=len(props_pc)
    if(sz)!=0:
      areap=[props_pc[i].area for i in range(sz)]
      #print(sz,areap)
      k=np.argmax(areap)
    
      xcp = props_pc[k].centroid[0] #x center
      ycp = props_pc[k].centroid[1] #y_center
      ap = props_pc[k].area
    else:
      xpc=0
      ypc=0
      ac=0
    
    xcc = props_cc[0].centroid[0] #x center
    ycc = props_cc[0].centroid[1] #y_center
    ac = props_cc[0].area


    
    if (ap>ac):
      ar=ac/ap
    else:
      ar=ap/ac
      
    dist=math.sqrt((xcp-xcc)*(xcp-xcc)+(ycp-ycc)*(ycp-ycc))
    cup_rr[i]=math.sqrt(ar)
    cup_dc[i]=dist
    cup_ac[i]=ac
    cup_ap[i]=ap
# Out:
# (128, 128)
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))

# %%
#print(cup_rr)
#print(cup_dc)
print('best radii ratio= {:0.2f}, worst radii ratio= {:0.2f}, worst center distance= {:0.2f}, best center distance= {:0.2f}'.format(np.amax(cup_rr),np.amin(cup_rr),np.amax(cup_dc),np.amin(cup_dc)))
bt90=cup_rr>.85
print('Percentage of images with less than 15% radius error ={:0.2f}'.format(sum(bt90)/test_s))
bt90=cup_rr>.9
print('Percentage of images with less than 10% radius error ={:0.2f}'.format(sum(bt90)/test_s))
# Out:
# best radii ratio= 0.99, worst radii ratio= 0.76, worst center distance= 3.32, best center distance= 0.24
# Percentage of images with less than 15% radius error =0.75
# Percentage of images with less than 10% radius error =0.38

# %% [markdown]
# ###Validation RIM

# %%
test_s=int(X_test2.shape[0])
test_s=test_s-test_s%8
test_s
# Out:
# 40

# %% [markdown]
# Acquiring scores for the validation set:

# %%
# %%time
pred_dice=np.empty((test_s), dtype=np.float32)
pred_iou=np.empty((test_s), dtype=np.float32)


#sess = K.get_session()

batch_X = X_test2[0:test_s]
batch_y = Y_test2[0:test_s]
print (batch_X.shape)
    
predv = (model.predict(batch_X)[...,0]>0.5).astype(np.float32)
corrv= (batch_y)[ ..., 0].astype(np.float32)


for i in tqdm_notebook(range(predv.shape[0])):
    #print('image #{}'.format(i))
    img = X_test[i]
    
    pred = predv[i]
    corr = corrv[i]
    cur_dice = np_dice_coef(pred, corr)
    cur_iou = np_iou(pred,corr)
    #print(cur_dice)
    pred_dice[i]=(cur_dice)
    pred_iou[i]=cur_iou
    
    
d_worst=np.amin(pred_dice)
d_best=np.amax(pred_dice)
d_mean=np.mean(pred_dice)
d_std=np.std(pred_dice)
print("Dice mean=",d_mean, " Std=",d_std, " best=",d_best," worst=",d_worst)

i_worst=np.amin(pred_iou)
i_best=np.amax(pred_iou)
i_mean=np.mean(pred_iou)
i_std=np.std(pred_iou)
print("IOU mean=",i_mean, " Std=",i_std, " best=",i_best," worst=",i_worst)

ix_best=np.argmax(pred_dice)
ix_worst=np.argmin(pred_dice)

j=0
for i in [ix_best,ix_worst]:
    print('image #{}'.format(i))
    img = X_test2[i]
    pred = predv[i]
    corr = corrv[i]
    
    print(pred_dice[i])
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    #ax.imshow(img)
    ax.imshow(img)
    ax.set_title('Image')
    #plt.show()
    fig.savefig(os.path.join('/content/gdrive/My Drive/FIG','imgRIM'+str(j)+name+'.png'),dpi=600)
    j+=1
# Out:
# (40, 128, 128, 3)
# HBox(children=(IntProgress(value=0, max=40), HTML(value='')))
# Dice mean= 0.8354105  Std= 0.09302984  best= 0.94905865  worst= 0.5975366
# IOU mean= 0.7277165  Std= 0.13026237  best= 0.9030557  worst= 0.42606223
# image #39
# 0.94905865
# image #27
# 0.5975366
# CPU times: user 4.61 s, sys: 1.04 s, total: 5.65 s
# Wall time: 4.89 s

# %%
cup_rr= np.empty((test_s), dtype=np.float32)
cup_dc= np.empty((test_s), dtype=np.float32)
cup_ac= np.empty((test_s), dtype=np.float32)
cup_ap= np.empty((test_s), dtype=np.float32)


predc = predv[0, ...].copy()
corrc= corrv[0, ...].copy()
print (predc.shape)

for i in tqdm_notebook(range(test_s), leave=True):
    
    predc = predv[i]
    corrc = corrv[i]
    
    label_pc = skimage.measure.label(predc, connectivity=predc.ndim)
    props_pc = skimage.measure.regionprops(label_pc)
    
    label_cc = skimage.measure.label(corrc, connectivity=corrc.ndim)
    props_cc = skimage.measure.regionprops(label_cc)
    
    sz=len(props_pc)
    if(sz)!=0:
      areap=[props_pc[i].area for i in range(sz)]
      #print(sz,areap)
      k=np.argmax(areap)
    
      xcp = props_pc[k].centroid[0] #x center
      ycp = props_pc[k].centroid[1] #y_center
      ap = props_pc[k].area
    else:
      xpc=0
      ypc=0
      ac=0
    
    xcc = props_cc[0].centroid[0] #x center
    ycc = props_cc[0].centroid[1] #y_center
    ac = props_cc[0].area


    
    if (ap>ac):
      ar=ac/ap
    else:
      ar=ap/ac
      
    dist=math.sqrt((xcp-xcc)*(xcp-xcc)+(ycp-ycc)*(ycp-ycc))
    cup_rr[i]=math.sqrt(ar)
    cup_dc[i]=dist
    cup_ac[i]=ac
    cup_ap[i]=ap
# Out:
# (128, 128)
# HBox(children=(IntProgress(value=0, max=40), HTML(value='')))

# %%
#print(cup_rr)
#print(cup_dc)
print('best radii ratio= {:0.2f}, worst radii ratio= {:0.2f}, worst center distance= {:0.2f}, best center distance= {:0.2f}'.format(np.amax(cup_rr),np.amin(cup_rr),np.amax(cup_dc),np.amin(cup_dc)))
bt90=cup_rr>.85
print('Percentage of images with less than 15% radius error ={:0.2f}'.format(sum(bt90)/test_s))
bt90=cup_rr>.9
print('Percentage of images with less than 10% radius error ={:0.2f}'.format(sum(bt90)/test_s))
# Out:
# best radii ratio= 0.99, worst radii ratio= 0.73, worst center distance= 15.92, best center distance= 0.11
# Percentage of images with less than 15% radius error =0.80
# Percentage of images with less than 10% radius error =0.62

# %% [markdown]
# ### Loading model
# Ajust files as needed

# %%
breakpoint
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-dc1edc8e2d97> in <module>()
# ----> 1 breakpoint
#
# NameError: name 'breakpoint' is not defined

# %%
tpu_model.load_weights(os.path.join('/content/gdrive/My Drive/GPU/'+name+'last_checkpoint_TPU.hdf5'))
